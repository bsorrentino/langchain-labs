# %% [markdown]
# [Invoice or Bill Custom Parsing using Kor (LangChain Extension), Generative Language Models & Prompt Engineering](https://blog.gopenai.com/invoice-or-bill-custom-parsing-using-kor-langchain-extension-generative-language-models-prompt-7133193358fa)

# %% [markdown]
# Iinitialize ChatOpenAI model.

# %%
import os

__USE_AZURE_OPENAI = True

if __USE_AZURE_OPENAI:
    import openai
    from langchain.chat_models import AzureChatOpenAI

    # Configure OpenAI API
    llm = AzureChatOpenAI(deployment_name="Document-Parsing", 
                        openai_api_key= os.getenv("AZURE_OPENAI_API_KEY"),
                        openai_api_version="2023-06-01-preview")
else:
    from langchain.chat_models import ChatOpenAI

    #load GPT 3.5 model
    llm = ChatOpenAI(
        model_name="gpt-3.5-turbo",
        temperature=0,
        max_tokens=2000,
        openai_api_key=os.environ["OPENAI_API_KEY"].rstrip()
    )

# %% [markdown]
# The next step is to create schema and provide examples

# %%
# import neccessary packages from korr
from kor.extraction import create_extraction_chain
from kor.nodes import Object, Text, Number

#object creation for invoice_number
header_schema = Object(
    id="header",
    description="header details",
    attributes=[
        Text(
            id="number",
            description= "unique number (identifier) of given purchase order",
        examples=[
            ( "PO NUMBER 12345", "PO NUMBER 35658")
        ]),
        Text(
            id="quote",
            description= "quote number",
        examples=[
            ( "QUOTE # 1-1604415497 (Bosch)", "QUOTE # \"1-1708903259, 109815 (1-1611484010), 108832 (1-1609457261), 108878\"")
        ]),
        Text(
            id="date",
            description= "date",
        ),
        Text(
            id="payment_terms",
            description= "get payment terms",
        examples=[
            ( "PAYMENT TERMS Net 45", "PAYMENT TERMS Net 30")
        ]),
        Text(
            id="shipping_terms",
            description= "get shipping terms",
        ),
        Text(
            id="currency",
            description= "currency",
        examples=[
            ( "CURRENCY EUR", "CURRENCY USD")
        ]),
        Text(
            id="contract",
            description= "contract",
        ),
        Text(
            id="contact",
            description= "primary contact",
            examples=[
                ("Racel Madamba  Racel_Rey.Madamba@genesys.com", 
                "Claire Wood claire.wood@genesys.com")
            ]
        ),
    ],

    many=False,
)

# %%
address_schema = Object(
    id="address",
    description="address details",
    attributes=[
        Text(id="name", description="the name of person and organization"),
        Text(id="address_line", description=""),
        Text(id="attn", description=""),
    ],
    examples=[
        (
            "Genesys Telecommunications Laboratories B.V. Gooimeer 6-02 Naarden, 1411 DD Netherlands Attn: ACCOUNTS PAYABLE Accounts.payableEMEA@genesys.com",
            {
                "name": "Genesys Telecommunications Laboratories B.V.",
                "address_line": "Gooimeer 6-02 Naarden, 1411 DD Netherlands",
                "attn": "Attn: ACCOUNTS PAYABLE Accounts.payableEMEA@genesys.com",
            },
        ),
        (
            "Genesys Telecommunications Laboratories Asia Pte Ltd. 9 Raffles Place,#18-02, Republic Plaza Republic Plaza, 048619 Singapore Attn: AP-AU@genesys.com ACCOUNTS PAYABLE",
            {
                "name": "Genesys Telecommunications Laboratories Asia Pte Ltd.",
                "address_line": "9 Raffles Place,#18-02, Republic Plaza Republic Plaza, 048619 Singapore",
                "attn": "Attn: AP-AU@genesys.com ACCOUNTS PAYABLE",
            },
        ),
        
       (
            "Genesys Laboratories Australasia Pty Ltd Level 20,141 Walker Street North Sydney, NSW 2060 Australia Attn: AP-AU@genesys.com ACCOUNTS PAYABLE",
            {
                "name": "Genesys Laboratories Australasia Pty Ltd",
                "address_line": "PLevel 20,141 Walker Street North Sydney, NSW 2060 Australia",
                "attn": "Attn: AP-AU@genesys.com ACCOUNTS PAYABLE",
            },
        ) 
    ],
    many=True,
)

# %% [markdown]
# prompt generated by **Kor** from our object definition to pass it to the GPT model.

# %%
products_schema = Object(
    id="lines",
    description="the details of bill",
    attributes=[
        Number(id="line", description=""),
        Text(id="description", description="the description of the product or service"),
        Text(id="description2", description="extra description of the product or service"),
        Text(id="price", description="price per unit"),
        Text(id="total", description="the total price, which is number of units * unit_price"),
    ],
    examples=[
        (
            "1 1-1708903259_CAS Renewal_01/01/2020 to 30/06/2021_NXO 2,789.50 2,789.50 FRANCE_La Poste_Solution Name: WDE Plugin for MS Dynamics CRM - add-on 130 seats",
            {
               "line": 1, 
               "description": "1-1708903259_CAS Renewal_01/01/2020 to 30/06/2021_NXO",
               "description2": "FRANCE_La Poste_Solution Name: WDE Plugin for MS Dynamics CRM - add-on 130 seats",
               "price": "2,789.50", 
               "total": "2,789.50",
            },
        ),
        (
            "4 108878_CAS Renewal_01/01/2020 to 30/06/2021_NXO 10,225.00 10,225.00 FRANCE_La Poste_Solution Name:MSCRM Dynamics Connector (730 seats) ",
            {
               "line": 4,
               "description": "108878_CAS Renewal_01/01/2020 to 30/06/2021_NXO",
               "description2": "FRANCE_La Poste_Solution Name:MSCRM Dynamics Connector (730 seats)",
               "price": "10,225.00", 
               "total": "10,225.00",
            },
        ),
        (
            "6 78822 (73377)_Premise CAS Renewal_01/01/2022 to 1,838.55 1,838.55 12/31/2022_IREN S.p.A._IREN S.p.A._SipVR Licensing - additional 50 licenses CAS Renewal ",
            {
               "line": 6,
               "description": "78822 (73377)_Premise CAS Renewal_01/01/2022 to",
               "description2": "12/31/2022_IREN S.p.A._IREN S.p.A._SipVR Licensing - additional 50 licenses CAS Renewal 1,838.55 1,838.55",
               "price": "1,838.55", 
               "total": "1,838.55",
            },
        ),
    ],
    many=True
)

# %% [markdown]
# Create a Purchase Order schema containing all previous defined sub schema

# %%
po_schema = Object(
    id="po",
    description="extraction of relevant information from purchase order",
    attributes=[
        header_schema,
        address_schema,
        products_schema
        
    ],
    many=False,
)

po_chain = create_extraction_chain(llm, po_schema, encoder_or_encoder_class="json", input_formatter=None)
po_chain_products = create_extraction_chain(llm, products_schema, encoder_or_encoder_class="json", input_formatter=None)

# %% [markdown]
# Load PDF file from google drive and use PDF Miner to extract raw text. Note: you need to download invoice to your local drive.

# %%
from pdfminer.layout import LAParams, LTTextBox, LTTextLine
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.high_level import extract_text

def extract_text_by_page(pdf_path):
    with open(pdf_path, 'rb') as fp:
        rsrcmgr = PDFResourceManager()
        device = PDFPageAggregator(rsrcmgr, laparams=LAParams())
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        pages = PDFPage.get_pages(fp)

        for page_num, page in enumerate(pages, start=1):
            interpreter.process_page(page)
            layout = device.get_result()
            text = ''
            for lt_obj in layout:
                if isinstance(lt_obj, LTTextBox) or isinstance(lt_obj, LTTextLine):
                    text += lt_obj.get_text()
            yield page_num, text

def extract_whole_text(pdf_path):
    text = extract_text(pdf_path)
    # perform basic processing to remove \n
    return " ".join(text.split("\n"))

# %%
import json

def parse_document(file_path):
    for page_num, page in extract_text_by_page(file_path):
        # Print the prompt  generated by Kor from our object definition to pass it to the GPT model.
        ## print(po_chain.prompt.format_prompt(text=page).to_string())
        print( f"PAGE# {page_num}" )
        if page_num == 1:
            parse_result_header = po_chain.run(text=page)
            print( json.dumps(parse_result_header['data']['po'], indent=4) )
        else:
            parse_result_lines = po_chain_products.run(text=page)
            if parse_result_lines['data'].get('lines') is not None:
                print( json.dumps(parse_result_lines['data']['lines'], indent=4) )
            else:
                print( parse_result_lines )
        
file_paths = ['doc_9.pdf', 'doc_10.pdf', 'doc_12.pdf', 'doc_8.pdf']

for file_path in file_paths:
    print( f"Parsing file: {file_path}" )
    parse_document( f"../docs/PO/{file_path}")
    print( "-----------------------------------\n\n" )
# Out:
# Parsing file: doc_9.pdf
# PAGE# 1
# {
#     "header": {
#         "number": "PO NUMBER 25027959",
#         "quote": "QUOTE # 28613",
#         "date": "04/10/2018",
#         "payment_terms": "PAYMENT TERMS Net 30",
#         "shipping_terms": null,
#         "currency": "CURRENCY EUR",
#         "contract": null,
#         "contact": "Anna Wojtkowska"
#     },
#     "address": [
#         {
#             "name": "8410 Smart Communications Technologies Ltd",
#             "address_line": "9 Seagrave Rd London, SW67RP United Kingdom",
#             "attn": "Attn: Anna Wojtkowska Anna.Wojtkowska@genesys.com"
#         },
#         {
#             "name": "Genesys Telecommunications Laboratories Asia Pte Ltd.",
#             "address_line": "9 Raffles Place,#18-02, Republic Plaza Republic Plaza, 048619 Singapore",
#             "attn": "Attn: AP-AU@genesys.com ACCOUNTS PAYABLE"
#         }
#     ],
#     "lines": [
#         {
#             "line": 1,
#             "description": "WDE Universal Connector for CRM (3rd Party Expert Apps) -",
#             "description2": "Qty: 110 Seats 9300002897",
#             "price": "5,065.30",
#             "total": "5,065.30"
#         },
#         {
#             "line": 2,
#             "description": "Custom App Support for WDE Universal Connector for CRM (3rd Party Expert Apps) -",
#             "description2": "Qty: 110 Seats 9300002897",
#             "price": "811.78",
#             "total": "811.78"
#         }
#     ]
# }
# -----------------------------------
#
#
# Parsing file: doc_10.pdf
# PAGE# 1
# {
#     "header": {
#         "number": "PO NUMBER 25649-2",
#         "quote": "QUOTE # \"LUTE1004 (1-1601390803) \"",
#         "date": "DATE 5/23/2019",
#         "payment_terms": "PAYMENT TERMS Net 45",
#         "shipping_terms": "SHIPPING TERMS",
#         "currency": "CURRENCY EUR",
#         "contract": "CONTRACT 4429",
#         "contact": "CONTACT Claire Wood claire.wood@genesys.com"
#     },
#     "address": [
#         {
#             "name": "Smart Communications Techn Ltd",
#             "address_line": "9 Seagrave Road London, SW6 7RP United Kingdom",
#             "attn": ""
#         },
#         {
#             "name": "Genesys Telecommunications Laboratories B.V.",
#             "address_line": "Gooimeer 6-02,1411 DD Naarden Naarden, 1411 Netherlands",
#             "attn": "Attn: Claire Wood"
#         },
#         {
#             "name": "Genesys Telecommunications Laboratories B.V.",
#             "address_line": "Gooimeer 6-02 Naarden, 1411 DD Netherlands",
#             "attn": "Attn: ACCOUNTS PAYABLE Accounts.payableEMEA@genesys.com"
#         }
#     ],
#     "lines": [
#         {
#             "line": 1,
#             "description": "LUTE1004 (1-1601390803) - Renewal of CAS (01 Jan 16 to 31 Dec 16) Italy",
#             "description2": "",
#             "price": "3,994.00",
#             "total": "3,994.00"
#         },
#         {
#             "line": 2,
#             "description": "LUTE1004 (1-1601390803) - Renewal of CAS (01 Jan 17 to 31 Dec 17) Italy",
#             "description2": "",
#             "price": "4,073.50",
#             "total": "4,073.50"
#         },
#         {
#             "line": 3,
#             "description": "LUTE1004 (1-1601390803) - Renewal of CAS (01 Jan 18 to 31 Dec 18) Italy",
#             "description2": "",
#             "price": "4,155.64",
#             "total": "4,155.64"
#         }
#     ]
# }
# -----------------------------------
#
#
# Parsing file: doc_12.pdf
# PAGE# 1
# {
#     "header": {
#         "number": "PO NUMBER 44788",
#         "quote": "QUOTE # 78285",
#         "date": "09/29/2020",
#         "payment_terms": "PAYMENT TERMS Net 30",
#         "shipping_terms": "",
#         "currency": "CURRENCY EUR",
#         "contract": "CONTRACT 3172",
#         "contact": "Enjay Yamio Ederlene.Yamio@genesys.com"
#     },
#     "address": [
#         {
#             "name": "Genesys Telecommunications Laboratories B.V.",
#             "address_line": "Gooimeer 6-02,1411 DD Naarden Naarden, 1411 Netherlands",
#             "attn": "Attn: Enjay Yamio"
#         }
#     ],
#     "lines": [
#         {
#             "line": 1,
#             "description": "78285_Unisystem_TBD_Fixed_120h @ 70 EUR/h Softphone",
#             "description2": "services BU SEI",
#             "price": "8,400.00",
#             "total": "8,400.00"
#         }
#     ]
# }
# -----------------------------------
#
#
# Parsing file: doc_8.pdf
# PAGE# 1
# {
#     "header": {
#         "number": "42852-2",
#         "quote": "QUOTE # 71090",
#         "date": "04/29/2020",
#         "payment_terms": "PAYMENT TERMS Net 90",
#         "shipping_terms": null,
#         "currency": "CURRENCY EUR",
#         "contract": "3172",
#         "contact": "Enjay Yamio Ederlene.Yamio@genesys.com"
#     },
#     "address": [
#         {
#             "name": "Genesys Telecommunications Laboratories B.V.",
#             "address_line": "Gooimeer 6-02,1411 DD Naarden Naarden, 1411 Netherlands",
#             "attn": "Attn: Enjay Yamio"
#         }
#     ],
#     "lines": [
#         {
#             "line": 1,
#             "description": "71090_PS Softphone-MS1 09.04.20 - 24.09.20_TBD",
#             "description2": "BU Italy",
#             "price": "54,200.00",
#             "total": "54,200.00"
#         },
#         {
#             "line": 2,
#             "description": "71090_PS Softphone-MS2 09.04.20 - 30.09.20_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         },
#         {
#             "line": 3,
#             "description": "71090_PS Softphone-MS3 01.05.20 - 31.09.20_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         },
#         {
#             "line": 4,
#             "description": "71090_PS Softphone-MS4 01.06.20 - 30.06.20_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         },
#         {
#             "line": 5,
#             "description": "71090_PS Softphone-MS5 01.07.20 - 31.07.20_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         },
#         {
#             "line": 6,
#             "description": "71090_PS Softphone-MS6 01.08.20 - 31.08.20_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         },
#         {
#             "line": 7,
#             "description": "71090_PS Softphone-MS7 01.09.20 - 31.08.20_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         },
#         {
#             "line": 8,
#             "description": "71090_PS Softphone-MS8 01.10.20 - 31.10.20_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         },
#         {
#             "line": 9,
#             "description": "71090_PS Softphone-MS9 01.11.20 - 30.11.20_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         },
#         {
#             "line": 10,
#             "description": "71090_PS Softphone-MS10 01.12.20 - 31.12.20_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         },
#         {
#             "line": 11,
#             "description": "71090_PS Softphone-MS11 01.01.21 - 31.01.21_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         },
#         {
#             "line": 12,
#             "description": "71090_PS Softphone-MS12 01.02.21 - 28.02.21_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         },
#         {
#             "line": 13,
#             "description": "71090_PS Softphone-MS13 01.03.21 - 31.03.21_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         },
#         {
#             "line": 14,
#             "description": "71090_PS Softphone-MS14 01.04.21 - 30.04.21_TBD",
#             "description2": "BU Italy",
#             "price": "26,400.00",
#             "total": "26,400.00"
#         }
#     ]
# }
# PAGE# 2
# [
#     {
#         "line": 15,
#         "description": "71090_PS Softphone-MS15 01.05.21 - 31.05.21_TBD",
#         "description2": "",
#         "price": "26,400.00",
#         "total": "26,400.00"
#     },
#     {
#         "line": 16,
#         "description": "71090_PS Softphone-MS16 01.06.21 - 30.06.21_TBD",
#         "description2": "",
#         "price": "26,400.00",
#         "total": "26,400.00"
#     },
#     {
#         "line": 17,
#         "description": "71090_PS Softphone-MS17 01.07.21 - 31.07.21_TBD",
#         "description2": "",
#         "price": "26,400.00",
#         "total": "26,400.00"
#     },
#     {
#         "line": 18,
#         "description": "71090_PS Softphone-MS18 01.08.21 - 31.08.21_TBD",
#         "description2": "",
#         "price": "26,400.00",
#         "total": "26,400.00"
#     },
#     {
#         "line": 19,
#         "description": "71090_PS Softphone-MS19 01.09.21 - 30.09.21_TBD",
#         "description2": "",
#         "price": "26,400.00",
#         "total": "26,400.00"
#     },
#     {
#         "line": 20,
#         "description": "71090_PS Softphone-MS20 01.10.21 - 31.10.21_TBD",
#         "description2": "",
#         "price": "26,400.00",
#         "total": "26,400.00"
#     },
#     {
#         "line": 21,
#         "description": "71090_PS Softphone-MS21 01.11.21 - 30.11.21_TBD",
#         "description2": "",
#         "price": "26,400.00",
#         "total": "26,400.00"
#     },
#     {
#         "line": 22,
#         "description": "71090_PS Softphone-MS22 01.12.21 - 31.12.21_TBD",
#         "description2": "",
#         "price": "26,400.00",
#         "total": "26,400.00"
#     },
#     {
#         "line": 23,
#         "description": "71090_PS Softphone-MS23 01.01.22 - 31.01.22_TBD",
#         "description2": "",
#         "price": "26,400.00",
#         "total": "26,400.00"
#     }
# ]
# -----------------------------------
