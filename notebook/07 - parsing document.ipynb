# %% [markdown]
# [Invoice or Bill Custom Parsing using Kor (LangChain Extension), Generative Language Models & Prompt Engineering](https://blog.gopenai.com/invoice-or-bill-custom-parsing-using-kor-langchain-extension-generative-language-models-prompt-7133193358fa)

# %% [markdown]
# Iinitialize ChatOpenAI model.

# %%
import os

__USE_AZURE_OPENAI = True

if __USE_AZURE_OPENAI:
    import openai
    from langchain.chat_models import AzureChatOpenAI

    # Configure OpenAI API
    llm = AzureChatOpenAI(deployment_name="document-parser", 
                        openai_api_key= os.getenv("AZURE_OPENAI_API_KEY"),
                        openai_api_version=os.getenv("AZURE_OPENAI_API_VERSION"))
else:
    from langchain.chat_models import ChatOpenAI

    #load GPT 3.5 model
    llm = ChatOpenAI(
        model_name="gpt-3.5-turbo",
        temperature=0,
        max_tokens=2000,
        openai_api_key=os.environ["OPENAI_API_KEY"].rstrip()
    )

# %% [markdown]
# The next step is to create schema and provide examples

# %%
# import neccessary packages from korr
from kor.extraction import create_extraction_chain
from kor.nodes import Object, Text, Number

#object creation for invoice_number
header_schema = Object(
    id="header",
    description="header details",
    attributes=[
        Text(
            id="number",
            description= "unique number (identifier) of given purchase order",
        examples=[
            ( "PO NUMBER 12345", "PO NUMBER 35658")
        ]),
        Text(
            id="quote",
            description= "quote number",
        examples=[
            ( "QUOTE # 1-1604415497 (Bosch)", "QUOTE # \"1-1708903259, 109815 (1-1611484010), 108832 (1-1609457261), 108878\"")
        ]),
        Text(
            id="date",
            description= "date",
        ),
        Text(
            id="payment_terms",
            description= "get payment terms",
        examples=[
            ( "PAYMENT TERMS Net 45", "PAYMENT TERMS Net 30")
        ]),
        Text(
            id="shipping_terms",
            description= "get shipping terms",
        ),
        Text(
            id="currency",
            description= "currency",
        examples=[
            ( "CURRENCY EUR", "CURRENCY USD")
        ]),
        Text(
            id="contract",
            description= "contract",
        ),
        Text(
            id="contact",
            description= "primary contact",
            examples=[
                ("Racel Madamba  Racel_Rey.Madamba@genesys.com", 
                "Claire Wood claire.wood@genesys.com")
            ]
        ),
    ],

    many=False,
)

# %%
address_schema = Object(
    id="address",
    description="address details",
    attributes=[
        Text(id="name", description="the name of person and organization"),
        Text(id="address_line", description=""),
        Text(id="attn", description=""),
    ],
    examples=[
        (
            "Genesys Telecommunications Laboratories B.V. Gooimeer 6-02 Naarden, 1411 DD Netherlands Attn: ACCOUNTS PAYABLE Accounts.payableEMEA@genesys.com",
            {
                "name": "Genesys Telecommunications Laboratories B.V.",
                "address_line": "Gooimeer 6-02 Naarden, 1411 DD Netherlands",
                "attn": "Attn: ACCOUNTS PAYABLE Accounts.payableEMEA@genesys.com",
            },
        ),
        (
            "Genesys Telecommunications Laboratories Asia Pte Ltd. 9 Raffles Place,#18-02, Republic Plaza Republic Plaza, 048619 Singapore Attn: AP-AU@genesys.com ACCOUNTS PAYABLE",
            {
                "name": "Genesys Telecommunications Laboratories Asia Pte Ltd.",
                "address_line": "9 Raffles Place,#18-02, Republic Plaza Republic Plaza, 048619 Singapore",
                "attn": "Attn: AP-AU@genesys.com ACCOUNTS PAYABLE",
            },
        ),
        
       (
            "Genesys Laboratories Australasia Pty Ltd Level 20,141 Walker Street North Sydney, NSW 2060 Australia Attn: AP-AU@genesys.com ACCOUNTS PAYABLE",
            {
                "name": "Genesys Laboratories Australasia Pty Ltd",
                "address_line": "PLevel 20,141 Walker Street North Sydney, NSW 2060 Australia",
                "attn": "Attn: AP-AU@genesys.com ACCOUNTS PAYABLE",
            },
        ) 
    ],
    many=True,
)

# %% [markdown]
# prompt generated by **Kor** from our object definition to pass it to the GPT model.

# %%
products_schema = Object(
    id="lines",
    description="the details of bill",
    attributes=[
        Number(id="line", description=""),
        Text(id="description", description="the description of the product or service"),
        Text(id="price", description="price per unit"),
        Text(id="total", description="the total price, which is number of units * unit_price"),
    ],
    examples=[
        (
            "4 EMEA/100446/CUSTOMER: NTT Germany AG & Co. KG/FINAL CUSTOMER: Deutsche Börse AG /WDE Connector for SAP C/4HANA Licenses (subscription)/Payment upon delivery/Dec 1 2023 to Dec 31 2024 Subscription",
            {
               "line": 4,
               "description": "EMEA/100446/CUSTOMER: NTT Germany AG & Co. KG/FINAL CUSTOMER: Deutsche Börse AG /WDE Connector for SAP C/4HANA Licenses (subscription)/Payment upon delivery/Dec 1 2023 to Dec 31 2024 Subscription",
               "price": "10,225.00", 
               "total": "10,225.00",
            },
        ),
        (
            "7 EMEA/75440/COVERAGE:01/01/2024 to 07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./Standalone CAS - SipVR 75 licenses CAS Renewal",
            {
               "line": 7,
               "description": "EMEA/75440/COVERAGE:01/01/2024 to 07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./Standalone CAS - SipVR 75 licenses CAS Renewal",
               "price": "1,838.55", 
               "total": "1,838.55",
            },
        ),
    ],
    many=True
)

# %% [markdown]
# Create a Purchase Order schema containing all previous defined sub schema

# %%
po_schema = Object(
    id="po",
    description="extraction of relevant information from purchase order",
    attributes=[
        header_schema,
        address_schema,
        products_schema
        
    ],
    many=False,
)

po_chain = create_extraction_chain(llm, po_schema, encoder_or_encoder_class="json", input_formatter=None)
po_chain_products = create_extraction_chain(llm, products_schema, encoder_or_encoder_class="json", input_formatter=None)

# %% [markdown]
# Load PDF file from google drive and use PDF Miner to extract raw text. Note: you need to download invoice to your local drive.

# %%
from pdfminer.layout import LAParams, LTTextBox, LTTextLine
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.high_level import extract_text

def extract_text_by_page(pdf_path):
    with open(pdf_path, 'rb') as fp:
        rsrcmgr = PDFResourceManager()
        device = PDFPageAggregator(rsrcmgr, laparams=LAParams())
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        pages = PDFPage.get_pages(fp)

        for page_num, page in enumerate(pages, start=1):
            interpreter.process_page(page)
            layout = device.get_result()
            text = ''
            for lt_obj in layout:
                if isinstance(lt_obj, LTTextBox) or isinstance(lt_obj, LTTextLine):
                    text += lt_obj.get_text()
            yield page_num, text

def extract_whole_text(pdf_path):
    text = extract_text(pdf_path)
    # perform basic processing to remove \n
    return " ".join(text.split("\n"))

# %%
import json, re

def parse_page(page_num, page):
    # Print the prompt  generated by Kor from our object definition to pass it to the GPT model.
    ## print(po_chain.prompt.format_prompt(text=page).to_string())
    print( f"PAGE# {page_num}", page )
    if page_num == 1:
        parse_result_header = po_chain.run(text=page)
        return parse_result_header['data']['po']
    else:
        parse_result_lines = po_chain_products.run(text=page)
        if parse_result_lines['data'].get('lines') is not None:
            return parse_result_lines['data']['lines']
        else:
            json_match = re.search(r'<json>(.*?)</json>', parse_result_lines['raw'])
            if not json_match is None:
                return json.loades(json_match.group(1))

def parse_document(file_path):
    for page_num, page in extract_text_by_page(file_path):
        while True:
            try:
                yield parse_page(page_num, page)
                break
            except Exception as e:
                print( f"Error parsing page {page_num}: {e}" )
                continue # Try again

        
file_paths = ['PO_63466.pdf']

for file_path in file_paths:
    print( f"Parsing file: {file_path}" )
    for result in parse_document( f"../docs/PO/{file_path}"):
        print( result, f"\n{type(result)}" )

    print( "-----------------------------------\n\n" )
# Out:
# Parsing file: PO_63466.pdf
# PAGE# 1 Please reference PO# on invoices sent directly to accounts@genesys.com. Thank you.
# 25031880 Softphone
# International Ltd
# 35 Princess Street
# Greater Manchester
# Rochdale, OL12 0HA
# United Kingdom
# monica@softphoneinternational.com
# Genesys
# PURCHASE ORDER
# PO NUMBER
# QUOTE #
# 63466
# ID: 61514 (1-18111235022) & ID
# 111214 (1-1707697968) & 65188 & 62257 & 75829 &
# 78822 & 75440 & 80525 & 87532 & 85700 & 89830
# & 89829 & 90855 & 94558
# DATE
# PAYMENT TERMS
# SHIPPING TERMS
# CURRENCY
# CONTRACT
# CONTACT
# 01/09/2024
# Net 45
# EUR
# Karen Ascan
# Karen.Tamonan@genesys.com
# Ship To
# Genesys Cloud Services B.V.
# Prins Bernhardplein 200
# Amsterdam, , 1097JB
# Netherlands
# Attn: Chris Boucher
# Bill To
# Genesys Cloud Services B.V.
# Prins Bernhardplein 200
# Amsterdam, 1097JB
# Netherlands
# Attn: ACCOUNTS PAYABLE
# accounts@genesys.com
# Line
# Description
# 1
# 2
# 3
# 4
# 5
# 6
# EMEA/61514 (1-18111235022)/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN
# S.p.A./SipVR - Sip Voice Recorder - 50 ports in HA
# CAS Renewal
# EMEA/ID 111214 (1-1707697968)/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./SIP
# VR HA - addon seats
# CAS Renewal
# EMEA/65188/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN
# S.p.A./IRETI TTS Messaggi Dissuasione Google
# CAS Renewal
# EMEA/62257/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN
# S.p.A./Workspace WDE Plug-in for Universal CRM multi-
# platform
# CAS Renewal
# EMEA/75829/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN
# S.p.A./Softphone Workspace Connector for Generic Web CRM
# - 163 Licenses
# CAS Renewal
# EMEA/78822/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN
# S.p.A./SipVR Licensing - additional 50 licenses
# CAS Renewal
# Need By
# Date
# Qty Unit Price
# Total
# 1,666.66 1,666.66
# 1,599.99 1,599.99
# 1,400.04 1,400.04
# 3,782.10 3,782.10
# 2,238.98 2,238.98
# 1,126.11 1,126.11
#
#
#
#
# {'header': {'number': 'PO NUMBER 63466', 'quote': 'QUOTE # "ID: 61514 (1-18111235022) & ID\n111214 (1-1707697968) & 65188 & 62257 & 75829 &\n78822 & 75440 & 80525 & 87532 & 85700 & 89830\n& 89829 & 90855 & 94558"', 'date': '01/09/2024', 'payment_terms': 'PAYMENT TERMS Net 45', 'shipping_terms': None, 'currency': 'CURRENCY EUR', 'contract': None, 'contact': 'Karen Ascan Karen.Tamonan@genesys.com'}, 'address': [{'name': 'Ship To', 'address_line': 'Genesys Cloud Services B.V.\nPrins Bernhardplein 200\nAmsterdam, , 1097JB\nNetherlands', 'attn': 'Attn: Chris Boucher'}, {'name': 'Bill To', 'address_line': 'Genesys Cloud Services B.V.\nPrins Bernhardplein 200\nAmsterdam, 1097JB\nNetherlands', 'attn': 'Attn: ACCOUNTS PAYABLE accounts@genesys.com'}], 'lines': [{'line': 1, 'description': 'EMEA/61514 (1-18111235022)/COVERAGE:01/01/2024 to\n07/31/2024/Customer:IREN S.p.A./End User:IREN\nS.p.A./SipVR - Sip Voice Recorder - 50 ports in HA\nCAS Renewal', 'price': '1,666.66', 'total': '1,666.66'}, {'line': 2, 'description': 'EMEA/ID 111214 (1-1707697968)/COVERAGE:01/01/2024 to\n07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./SIP\nVR HA - addon seats\nCAS Renewal', 'price': '1,599.99', 'total': '1,599.99'}, {'line': 3, 'description': 'EMEA/65188/COVERAGE:01/01/2024 to\n07/31/2024/Customer:IREN S.p.A./End User:IREN\nS.p.A./IRETI TTS Messaggi Dissuasione Google\nCAS Renewal', 'price': '1,400.04', 'total': '1,400.04'}, {'line': 4, 'description': 'EMEA/62257/COVERAGE:01/01/2024 to\n07/31/2024/Customer:IREN S.p.A./End User:IREN\nS.p.A./Workspace WDE Plug-in for Universal CRM multi-\nplatform\nCAS Renewal', 'price': '3,782.10', 'total': '3,782.10'}, {'line': 5, 'description': 'EMEA/75829/COVERAGE:01/01/2024 to\n07/31/2024/Customer:IREN S.p.A./End User:IREN\nS.p.A./Softphone Workspace Connector for Generic Web CRM\n- 163 Licenses\nCAS Renewal', 'price': '2,238.98', 'total': '2,238.98'}, {'line': 6, 'description': 'EMEA/78822/COVERAGE:01/01/2024 to\n07/31/2024/Customer:IREN S.p.A./End User:IREN\nS.p.A./SipVR Licensing - additional 50 licenses\nCAS Renewal', 'price': '1,126.11', 'total': '1,126.11'}]}
# <class 'dict'>
# PAGE# 2 7
# 8
# 9
# 10
# 11
# 12
# 13
# EMEA/75440/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN
# S.p.A./Standalone CAS - SipVR 75 licenses
# CAS Renewal
# EMEA/80525/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN
# S.p.A./Softphone SIP Voice Recorder Licensing-25 Seat Count
# CAS Renewal
# EMEA/87532/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN
# S.p.A./Softphone Workspace Connector for Generic Web CRM
# Licensing_20 Seat Count
# CAS Renewal
# EMEA/85700/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN
# S.p.A./Softphone SIP Voice Recorder Licensing_20 Seat
# CAS Renewal
# EMEA/89830/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN
# S.p.A./Softphone Workspace Connector for Generic Web CRM
# Licensing (2 CRM)_80 Seat Counts
# CAS Renewal
# EMEA/89829/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN
# S.p.A./Softphone SIP Voice Recorder Licensing_80 Seat
# Counts
# CAS Renewal
# EMEA/90855/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN
# S.p.A./Softphone Workspace Connector for Generic Web CRM
# Licensing_400 Seat Counts
# CAS Renewal
# 14
# EMEA/94558/COVERAGE:01/01/2024 to
# 07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./Tool
# Gestione Sintesi Vocale Standalone CAS Softphone
# CAS Renewal
# 1,892.63 1,892.63
# 569.68 569.68
# 490.82 490.82
# 450.19 450.19
# 2,299.04 2,299.04
# 1,531.25 1,531.25
# 3,347.73 3,347.73
# 1,108.34 1,108.34
# 23,503.56 EUR
# Note to Supplier:
# IMPORTANT. Unless there is an existing contract between Vendor and Genesys applicable to the transaction subject
# matter of this Purchase Order, this Purchase Order shall be subject to the accompanying terms and conditions.
# https://genbin.genesys.com/media/Purchase_Order_Terms_&_Conditions_(Genesys)(2019-03-14).pdf
# VAT No: NL8081 86 838B01 Reg No: 24293219
#
#
# [{'line': 7, 'description': 'EMEA/75440/COVERAGE:01/01/2024 to 07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./Standalone CAS - SipVR 75 licenses CAS Renewal', 'price': '1,838.55', 'total': '1,838.55'}, {'line': 8, 'description': 'EMEA/80525/COVERAGE:01/01/2024 to 07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./Softphone SIP Voice Recorder Licensing-25 Seat Count CAS Renewal', 'price': '569.68', 'total': '569.68'}, {'line': 9, 'description': 'EMEA/87532/COVERAGE:01/01/2024 to 07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./Softphone Workspace Connector for Generic Web CRM Licensing_20 Seat Count CAS Renewal', 'price': '490.82', 'total': '490.82'}, {'line': 10, 'description': 'EMEA/85700/COVERAGE:01/01/2024 to 07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./Softphone SIP Voice Recorder Licensing_20 Seat CAS Renewal', 'price': '450.19', 'total': '450.19'}, {'line': 11, 'description': 'EMEA/89830/COVERAGE:01/01/2024 to 07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./Softphone Workspace Connector for Generic Web CRM Licensing (2 CRM)_80 Seat Counts CAS Renewal', 'price': '2,299.04', 'total': '2,299.04'}, {'line': 12, 'description': 'EMEA/89829/COVERAGE:01/01/2024 to 07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./Softphone SIP Voice Recorder Licensing_80 Seat Counts CAS Renewal', 'price': '1,531.25', 'total': '1,531.25'}, {'line': 13, 'description': 'EMEA/90855/COVERAGE:01/01/2024 to 07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./Softphone Workspace Connector for Generic Web CRM Licensing_400 Seat Counts CAS Renewal', 'price': '3,347.73', 'total': '3,347.73'}, {'line': 14, 'description': 'EMEA/94558/COVERAGE:01/01/2024 to 07/31/2024/Customer:IREN S.p.A./End User:IREN S.p.A./Tool Gestione Sintesi Vocale Standalone CAS Softphone CAS Renewal', 'price': '23,503.56', 'total': '23,503.56'}]
# <class 'list'>
# -----------------------------------
